# %%
import moleculegraph
import numpy as np
import toml
import glob
from moleculegraph.funcs import read_pair_potentials, read_bond_potentials, read_angle_potentials, read_torsion_potentials

# %%
pair_pots    = read_pair_potentials(glob.glob("examples/UA_devel/pair_potentials")[0])
bond_pots    = read_bond_potentials(glob.glob("examples/UA_devel/bond_potentials")[0])
angle_pots   = read_angle_potentials(glob.glob("examples/UA_devel/angle_potentials")[0])
torsion_pots = read_torsion_potentials(glob.glob("examples/UA_devel/torsion_potentials")[0])
  
# --> build toml files from those... ;)

forcefield = {}
forcefield["atoms"]    = pair_pots
forcefield["bonds"]    = bond_pots
forcefield["angles"]   = angle_pots
forcefield["torsions"] = torsion_pots

import toml
output_file_name = "examples/forcefield_mc.toml"
with open(output_file_name, "w") as toml_file:
    toml.dump(forcefield, toml_file)

# %%
pair_pots    = read_pair_potentials(glob.glob("examples/UA_devel/pair_potentials")[0])
bond_pots    = read_bond_potentials(glob.glob("examples/UA_devel/bond_potentials")[0])
angle_pots   = read_angle_potentials(glob.glob("examples/UA_devel/angle_potentials")[0])
torsion_pots = read_torsion_potentials(glob.glob("examples/UA_devel/torsion_potentials")[0])

KB_kcal = 0.001985875
for p in pair_pots:
    #print(p)
    pair_pots[p]["style"] = "Mie"
for p in bond_pots:
    #print(p)
    bond_pots[p]["style"]          = "fixed"
    #print(bond_pots[p])
for p in angle_pots:
    #print(p)
    angle_pots[p]["style"]          = "harmonic"
    angle_pots[p]["p"][0]           /= 2
for p in torsion_pots:
    #print(p)
    torsion_pots[p]["style"]          = "opls"
    
# --> build toml files from those... ;)

forcefield = {}
forcefield["atoms"]    = pair_pots
forcefield["bonds"]    = bond_pots
forcefield["angles"]   = angle_pots
forcefield["torsions"] = torsion_pots


import toml
output_file_name = "examples/forcefield_cassandra.toml"
with open(output_file_name, "w") as toml_file:
    toml.dump(forcefield, toml_file)

# %%
import glob
from moleculegraph.funcs import read_pair_potentials, read_bond_potentials, read_angle_potentials, read_torsion_potentials


pair_pots    = read_pair_potentials(glob.glob("examples/UA_devel/pair_potentials")[0])
bond_pots    = read_bond_potentials(glob.glob("examples/UA_devel/bond_potentials")[0])
angle_pots   = read_angle_potentials(glob.glob("examples/UA_devel/angle_potentials")[0])
torsion_pots = read_torsion_potentials(glob.glob("examples/UA_devel/torsion_potentials")[0])

KB_kcal = 0.001985875
for p in pair_pots:
    #print(p)
    pair_pots[p]["style"]   = "hybrid Mie/cut coul/long"
    pair_pots[p]["epsilon"] = round(pair_pots[p]["epsilon"]*KB_kcal,4)
for p in bond_pots:
    #print(p)
    bond_pots[p]["style"]        = "harmonic"
    bond_force = 300.
    bond_pots[p]["p"][1]         = bond_force
    print("bond_force set to:",bond_force)
    print("for details check: https://doi.org/10.1021/acs.jced.9b01031")
    #print(bond_pots[p])
for p in angle_pots:
    #print(p)
    angle_pots[p]["style"]          = "harmonic"
    angle_pots[p]["p"][1]           = round(angle_pots[p]["p"][1]*KB_kcal/2,4)
for p in torsion_pots:
    #print(p) 
    torsion_pots[p]["style"]     = "opls"
    torsion_pots[p]["p"]       = [ round(x*KB_kcal*2,4) for x in torsion_pots[p]["p"] ]
    
# --> build toml files from those... ;)

forcefield = {}
forcefield["atoms"]    = pair_pots
forcefield["bonds"]    = bond_pots
forcefield["angles"]   = angle_pots
forcefield["torsions"] = torsion_pots

import toml
output_file_name = "examples/forcefield_lammps.toml"
with open(output_file_name, "w") as toml_file:
    toml.dump(forcefield, toml_file)

# %%
angle_pots
# Out:
# {'[CH3_alkane][CH2_alkane][CH3_alkane]': {'list': ['CH3_alkane',
#    'CH2_alkane',
#    'CH3_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_alkane][CH2_alkane]': {'list': ['CH2_alkane',
#    'CH2_alkane',
#    'CH2_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_alkane][CH3_alkane]': {'list': ['CH3_alkane',
#    'CH2_alkane',
#    'CH2_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_alkane][CH2_amine]': {'list': ['CH2_alkane',
#    'CH2_alkane',
#    'CH2_amine'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_alkane][NH2_amine]': {'list': ['CH2_alkane',
#    'CH2_alkane',
#    'NH2_amine'],
#   'type': 2,
#   'p': [109.5, 56.2003],
#   'style': 'harmonic'},
#  '[CH2_amine][CH2_alkane][CH3_alkane]': {'list': ['CH3_alkane',
#    'CH2_alkane',
#    'CH2_amine'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH3_alkane][CH2_alkane][NH2_amine]': {'list': ['CH3_alkane',
#    'CH2_alkane',
#    'NH2_amine'],
#   'type': 2,
#   'p': [109.5, 56.2003],
#   'style': 'harmonic'},
#  '[CH2_alkane][NH2_amine][cH_amine]': {'list': ['CH2_alkane',
#    'NH2_amine',
#    'cH_amine'],
#   'type': 2,
#   'p': [112.9, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_amine][NH2_amine]': {'list': ['CH2_alkane',
#    'CH2_amine',
#    'NH2_amine'],
#   'type': 2,
#   'p': [109.5, 56.2003],
#   'style': 'harmonic'},
#  '[CH3_alkane][CH2_amine][NH2_amine]': {'list': ['CH3_alkane',
#    'CH2_amine',
#    'NH2_amine'],
#   'type': 2,
#   'p': [109.5, 56.2003],
#   'style': 'harmonic'},
#  '[CH2_amine][NH2_amine][cH_amine]': {'list': ['CH2_amine',
#    'NH2_amine',
#    'cH_amine'],
#   'type': 2,
#   'p': [112.9, 62.0586],
#   'style': 'harmonic'},
#  '[cH_amine][NH2_amine][cH_amine]': {'list': ['cH_amine',
#    'NH2_amine',
#    'cH_amine'],
#   'type': 2,
#   'p': [106.4, 43.5999],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH_branch][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH_branch',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [112.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH_branch][CH2_alkane][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'CH_branch'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_2branch][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'C_2branch',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [109.47, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][C_2branch]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'C_2branch'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_cyc6][CH2_cyc6][CH2_cyc6]': {'list': ['CH2_cyc6',
#    'CH2_cyc6',
#    'CH2_cyc6'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_cyc5][CH2_cyc5][CH2_cyc5]': {'list': ['CH2_cyc5',
#    'CH2_cyc5',
#    'CH2_cyc5'],
#   'type': 2,
#   'p': [105.5, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_olefin][CH_olefin][CHxx_alkane]': {'list': ['CH2_olefin',
#    'CH_olefin',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [119.7, 69.9227],
#   'style': 'harmonic'},
#  '[CH_olefin][CH_olefin][CHxx_alkane]': {'list': ['CH_olefin',
#    'CH_olefin',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [119.7, 69.9227],
#   'style': 'harmonic'},
#  '[CH_oleCis][CH_oleCis][CHxx_alkane]': {'list': ['CH_oleCis',
#    'CH_oleCis',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [119.7, 69.9227],
#   'style': 'harmonic'},
#  '[CH_oleTra][CH_oleTra][CHxx_alkane]': {'list': ['CH_oleTra',
#    'CH_oleTra',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [119.7, 69.9227],
#   'style': 'harmonic'},
#  '[CH_olefin][CH2_alkane][CHxx_alkane]': {'list': ['CH_olefin',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH_oleCis][CH2_alkane][CHxx_alkane]': {'list': ['CH_oleCis',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH_oleTra][CH2_alkane][CHxx_alkane]': {'list': ['CH_oleTra',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][O_dme][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'O_dme',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [112.0, 59.9734],
#   'style': 'harmonic'},
#  '[CHxx_alkane][O_ether][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'O_ether',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [112.0, 59.9734],
#   'style': 'harmonic'},
#  '[CH3_alksht][O_ether][CH3_alksht]': {'list': ['CH3_alksht',
#    'O_ether',
#    'CH3_alksht'],
#   'type': 2,
#   'p': [112.0, 59.9734],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][O_ether]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'O_ether'],
#   'type': 2,
#   'p': [112.0, 49.9448],
#   'style': 'harmonic'},
#  '[CH3_alkyne][C_alkyne][C_alkyne]': {'list': ['CH3_alkyne',
#    'C_alkyne',
#    'C_alkyne'],
#   'type': 2,
#   'p': [180.0, 18.986],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_ketone][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'C_ketone',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [117.2, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_ketone][O_ketone]': {'list': ['CHxx_alkane',
#    'C_ketone',
#    'O_ketone'],
#   'type': 2,
#   'p': [121.4, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][C_ketone]': {'list': ['C_ketone',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_acetone][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'C_acetone',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [117.2, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_acetone][O_acetone]': {'list': ['CHxx_alkane',
#    'C_acetone',
#    'O_acetone'],
#   'type': 2,
#   'p': [121.4, 62.0586],
#   'style': 'harmonic'},
#  '[CH_aldehyde][CH2_alkane][CHxx_alkane]': {'list': ['CH_aldehyde',
#    'CH2_alkane',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH_aldehyde][O_aldehyde]': {'list': ['O_aldehyde',
#    'CH_aldehyde',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [121.4, 62.0586],
#   'style': 'harmonic'},
#  '[N_forN2][N_forN2][c_Z_N2]': {'list': ['N_forN2', 'N_forN2', 'c_Z_N2'],
#   'type': 1,
#   'p': [0.0, 0.0],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][O_formate]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'O_formate'],
#   'type': 2,
#   'p': [108.8, 87.7935],
#   'style': 'harmonic'},
#  '[CH_formate][O_formate][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'O_formate',
#    'CH_formate'],
#   'type': 2,
#   'p': [116.4, 72.0575],
#   'style': 'harmonic'},
#  '[O=formate][CH_formate][O_formate]': {'list': ['O_formate',
#    'CH_formate',
#    'O=formate'],
#   'type': 2,
#   'p': [126.6, 135.9232],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][O_ester]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'O_ester'],
#   'type': 2,
#   'p': [108.8, 87.7935],
#   'style': 'harmonic'},
#  '[CHxx_alkane][O_ester][C_ester]': {'list': ['CHxx_alkane',
#    'O_ester',
#    'C_ester'],
#   'type': 2,
#   'p': [115.0, 62.0586],
#   'style': 'harmonic'},
#  '[O=ester][C_ester][O_ester]': {'list': ['O_ester', 'C_ester', 'O=ester'],
#   'type': 2,
#   'p': [125.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_ester][O_ester]': {'list': ['O_ester',
#    'C_ester',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [110.0, 70.1014],
#   'style': 'harmonic'},
#  '[CHxx_alkane][C_ester][O=ester]': {'list': ['O=ester',
#    'C_ester',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [125.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH2_alkane][C_ester]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'C_ester'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_alcohol][OH_alcohol][cH_alcohol]': {'list': ['CH2_alcohol',
#    'OH_alcohol',
#    'cH_alcohol'],
#   'type': 2,
#   'p': [107.4, 45.6354],
#   'style': 'harmonic'},
#  '[CH2_alkane][CH2_alcohol][OH_alcohol]': {'list': ['CH2_alkane',
#    'CH2_alcohol',
#    'OH_alcohol'],
#   'type': 2,
#   'p': [113.5, 61.8104],
#   'style': 'harmonic'},
#  '[CH2_alcohol][CH2_alkane][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'CH2_alcohol'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CH2_EOH][OH_EOH][cH_EOH]': {'list': ['CH2_EOH', 'OH_EOH', 'cH_EOH'],
#   'type': 2,
#   'p': [107.4, 45.6354],
#   'style': 'harmonic'},
#  '[CH3_alkane][CH2_EOH][OH_EOH]': {'list': ['CH3_alkane', 'CH2_EOH', 'OH_EOH'],
#   'type': 2,
#   'p': [113.5, 61.8104],
#   'style': 'harmonic'},
#  '[CH3_MeOH][O_MeOH][cH_MeOH]': {'list': ['CH3_MeOH', 'O_MeOH', 'cH_MeOH'],
#   'type': 2,
#   'p': [107.4, 45.6354],
#   'style': 'harmonic'},
#  '[CH3_MeOH_V][O_MeOH_V][cH_MeOH_V]': {'list': ['CH3_MeOH_V',
#    'O_MeOH_V',
#    'cH_MeOH_V'],
#   'type': 1,
#   'p': [108.53, 0.0],
#   'style': 'harmonic'},
#  '[CH_alc_sec][OH_alc_sec][cH_alc_sec]': {'list': ['CH_alc_sec',
#    'OH_alc_sec',
#    'cH_alc_sec'],
#   'type': 2,
#   'p': [107.4, 45.6354],
#   'style': 'harmonic'},
#  '[CH3_alkane][CH_alc_sec][OH_alc_sec]': {'list': ['CH3_alkane',
#    'CH_alc_sec',
#    'OH_alc_sec'],
#   'type': 2,
#   'p': [113.5, 61.8104],
#   'style': 'harmonic'},
#  '[CH_alc_sec][CH2_alkane][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH2_alkane',
#    'CH_alc_sec'],
#   'type': 2,
#   'p': [114.0, 62.0586],
#   'style': 'harmonic'},
#  '[CHxx_alkane][CH_alc_sec][CHxx_alkane]': {'list': ['CHxx_alkane',
#    'CH_alc_sec',
#    'CHxx_alkane'],
#   'type': 2,
#   'p': [112.0, 62.0586],
#   'style': 'harmonic'}}

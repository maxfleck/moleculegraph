# %%
import moleculegraph
import numpy as np
import toml
import unittest
import networkx as nx
import matplotlib.pyplot as plt

# %%
#gly = "[OH][C][b1][=O][C][NH2]" 
#ala = "[OH][C][b1][=O][C][b1][C][NH2]" 
#arg = "[OH][C][b1][=O][C][b5][C][C][C][NH][b1][NH][H2N][NH2]" 
#phe = "[OH][C][b1][=O][C][b7][C][C1][C2][C3][C4][C5][C6][r6][NH2]" 

gly = "[C][b1][=O][C][NH]" 
ala = "[C][b1][=O][C][b1][CH3][NH]" 
arg = "[C][b1][=O][C][b5][C][C][C][NH][b1][NH][H2N][NH]" 
phe = "[C][b1][=O][C][b7][C][C1][C2][C3][C4][C5][C6][r6][NH]" 

amino_acids = {}
amino_acids["gly"] = gly
amino_acids["ala"] = ala
amino_acids["arg"] = arg
amino_acids["phe"] = phe

# %%
for aa in amino_acids:
    dummy = moleculegraph.molecule(amino_acids[aa])
    dummy.visualize()

# %%
protein = "[ala][gly][phe][gly][arg][ala][ala][arg][ala][gly]"
#protein = "[ala][ala][gly]"

protein_aa = moleculegraph.molecule(protein)

protein_aa.visualize()

# %%
full_protein_string = "".join(protein_aa.map_molecule_via_atom_names(amino_acids))
print(full_protein_string)

full_protein = moleculegraph.molecule(full_protein_string)

full_protein.visualize()
# Out:
# [C][b1][=O][C][b1][CH3][NH][C][b1][=O][C][NH][C][b1][=O][C][b7][C][C1][C2][C3][C4][C5][C6][r6][NH][C][b1][=O][C][NH][C][b1][=O][C][b5][C][C][C][NH][b1][NH][H2N][NH][C][b1][=O][C][b1][CH3][NH][C][b1][=O][C][b1][CH3][NH][C][b1][=O][C][b5][C][C][C][NH][b1][NH][H2N][NH][C][b1][=O][C][b1][CH3][NH][C][b1][=O][C][NH]
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# Error in get_atom_no: not an atom
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [84], in <cell line: 4>()
#       1 full_protein_string = "".join(protein_aa.map_molecule_via_atom_names(amino_acids))
#       2 print(full_protein_string)
# ----> 4 full_protein = moleculegraph.molecule(full_protein_string)
#       6 full_protein.visualize()
#
# File /usr/local/lib/python3.10/dist-packages/moleculegraph-0.0.1-py3.10.egg/moleculegraph/__init__.py:134, in molecule.__init__(self, mol)
#     131 """array of keys of all dihedral forming atoms (separated by 3 bonds)"""
#     133 # get bond list
# --> 134 self.get_neighbour_list()
#     136 # get branch ends
#     137 n, count = np.unique(self.bond_list, return_counts=True)
#
# File /usr/local/lib/python3.10/dist-packages/moleculegraph-0.0.1-py3.10.egg/moleculegraph/__init__.py:350, in molecule.get_neighbour_list(self)
#     347 self.idx_bond_list = bond_list
#     348 self.ring_root_indexes = np.array(self.ring_root_indexes)
# --> 350 self.neighbour_list = np.vectorize(self.get_atom_no)(self.idx_neighbour_list)
#     351 self.bond_list = self.neighbour_list
#     352 return self.neighbour_list, self.idx_neighbour_list
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2328, in vectorize.__call__(self, *args, **kwargs)
#    2325     vargs = [args[_i] for _i in inds]
#    2326     vargs.extend([kwargs[_n] for _n in names])
# -> 2328 return self._vectorize_call(func=func, args=vargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/function_base.py:2411, in vectorize._vectorize_call(self, func, args)
#    2408 # Convert args to object arrays first
#    2409 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2411 outputs = ufunc(*inputs)
#    2413 if ufunc.nout == 1:
#    2414     res = asanyarray(outputs, dtype=otypes[0])
#
# File /usr/local/lib/python3.10/dist-packages/moleculegraph-0.0.1-py3.10.egg/moleculegraph/__init__.py:440, in molecule.get_atom_no(self, idx)
#     438 idx = int(idx)
#     439 if self.f[idx] >= 0:
# --> 440     no = int(np.squeeze(np.where(self.atom_indexes == idx)))
#     441     assert no == self.n[idx], "atom numbers dont work"
#     442     return no
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
graph = nx.Graph()
for b0, b1 in full_protein.bond_list:
    graph.add_edge(b0, b1)

labels = {}
for i, name in enumerate(full_protein.atom_names):
    labels[i] = name

pos = nx.kamada_kawai_layout(graph)

nx.draw_networkx(graph, pos, labels=labels, )
nx.draw_networkx_labels(graph, pos, labels, font_size=12, font_color="black")

ax = plt.gca()
plt.axis("off")
plt.tight_layout()

plt.show()

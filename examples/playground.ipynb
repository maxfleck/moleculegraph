# %%
import moleculegraph
import numpy as np

# %%
gly = "[OH][C][b1][=O][C][NH2]"

molecule = moleculegraph.molecule(gly)
molecule.visualize()

# %%
molecule.bond_list
# Out:
# array([[0, 1],
#        [1, 3],
#        [3, 4],
#        [1, 2]])
